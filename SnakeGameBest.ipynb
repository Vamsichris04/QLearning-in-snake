# %% [markdown]
# # Setup

# %%
import itertools
import json

sqs = [''.join(s) for s in list(itertools.product(*[['0','1']] * 4))]
widths = ['0','1','NA']
heights = ['2','3','NA']
direction = [0,1,2,3]

states = {}
for i in widths:
	for j in heights:
		for k in sqs:
			for l in direction:
				states[str((i,j,k, l))] = [0,0,0,0]	

with open("qvalues.json", "w") as f:
	json.dump(states, f)

# %% [markdown]
# # Learner

# %%
import random
import json

import dataclasses

@dataclasses.dataclass
class GameState:
    distance: tuple
    position: tuple
    surroundings: str
    food: tuple
    direction: int


class Learner(object):
    def __init__(self, display_width, display_height, block_size):
        # Game parameters
        self.display_width = display_width
        self.display_height = display_height
        self.block_size = block_size

        # Learning parameters
        self.epsilon = 1
        self.epsilon_decay = 0.9992
        self.epsilon_min = 0.005
        self.lr = 0.03
        self.discount = .8

        # State/Action history
        self.qvalues = self.LoadQvalues()
        self.history = []

        # Action space
        self.actions = {
            0:'left',
            1:'right',
            2:'up',
            3:'down'
        }

    def Reset(self):
        self.history = []
        
    #def UploadQvalues(self, path"qvalues.json"):
        
    

    def LoadQvalues(self, path= "qvalues.json"):
        with open(path, "r") as f:
            qvalues = json.load(f)
        return qvalues

    def SaveQvalues(self, path="qvalues.json"):
        with open(path, "w") as f:
            print("here")
            json.dump(self.qvalues, f)
            
    def act(self, dir, snake, food):
        state = self._GetState(dir, snake, food)

        # Epsilon greedy
        rand = random.uniform(0,1)
        if rand < self.epsilon:
            action_key = random.choices(list(self.actions.keys()))[0]
        else:
            state_scores = self.qvalues[self._GetStateStr(state)]
            action_key = state_scores.index(max(state_scores))
        action_val = self.actions[action_key]
        
        # Remember the actions it took at each state
        self.history.append({
            'state': state,
            'action': action_key
            })
        return action_val
    
    def UpdateQValues(self, reason):
        history = self.history[::-1]
        for i, h in enumerate(history[:-1]):
            if reason: # Snake Died -> Negative reward
                sN = history[0]['state']
                aN = history[0]['action']
                state_str = self._GetStateStr(sN)
                if(reason == 'Steps'):
                    reward = -3
                reward = -30
                self.qvalues[state_str][aN] = (1-self.lr) * self.qvalues[state_str][aN] + self.lr * reward # Bellman equation - there is no future state since game is over
                reason = None
            else:
                s1 = h['state'] # current state
                s0 = history[i+1]['state'] # previous state
                a0 = history[i+1]['action'] # action taken at previous state
                
                x1 = s0.distance[0] # x distance at current state
                y1 = s0.distance[1] # y distance at current state
    
                x2 = s1.distance[0] # x distance at previous state
                y2 = s1.distance[1] # y distance at previous state
                
                if s0.food != s1.food: # Snake ate a food, positive reward
                    reward = 5
                elif (abs(x1) > abs(x2) or abs(y1) > abs(y2)): # Snake is closer to the food, positive reward
                    reward = 0.0001
                else:
                    reward = -0.0001 # Snake is further from the food, negative reward
                    
                state_str = self._GetStateStr(s0)
                new_state_str = self._GetStateStr(s1)
                self.qvalues[state_str][a0] = (1-self.lr) * (self.qvalues[state_str][a0]) + self.lr * (reward + self.discount*max(self.qvalues[new_state_str])) # Bellman equation


    def _GetState(self, dir, snake, food):
        snake_head = snake[-1]
        dist_x = food[0] - snake_head[0]
        dist_y = food[1] - snake_head[1]

        if dist_x > 0:
            pos_x = '1' # Food is to the right of the snake
        elif dist_x < 0:
            pos_x = '0' # Food is to the left of the snake
        else:
            pos_x = 'NA' # Food and snake are on the same X file

        if dist_y > 0:
            pos_y = '3' # Food is below snake
        elif dist_y < 0:
            pos_y = '2' # Food is above snake
        else:
            pos_y = 'NA' # Food and snake are on the same Y file

        sqs = [
            (snake_head[0]-self.block_size, snake_head[1]),   
            (snake_head[0]+self.block_size, snake_head[1]),         
            (snake_head[0],                  snake_head[1]-self.block_size),
            (snake_head[0],                  snake_head[1]+self.block_size),
        ]
        
        surrounding_list = []
        for sq in sqs:
            if sq[0] < 0 or sq[1] < 0: # off screen left or top
                surrounding_list.append('1')
            elif sq[0] >= self.display_width or sq[1] >= self.display_height: # off screen right or bottom
                surrounding_list.append('1')
            elif sq in snake[:-1]: # part of tail
                surrounding_list.append('1')
            else:
                surrounding_list.append('0')
        surroundings = ''.join(surrounding_list)

        return GameState((dist_x, dist_y), (pos_x, pos_y), surroundings, food, dir)

    def _GetStateStr(self, state):
        return str((state.position[0],state.position[1],state.surroundings, state.direction))

# %%
#%%
import pygame
import random
#import Learner

pygame.init()

#%% CONSTANTS
YELLOW = (255, 255, 102)
BLACK = (0, 0, 0)
GREEN = (0, 255, 0)
BLUE = (50, 153, 213)

BLOCK_SIZE = 10 
DIS_WIDTH = 600
DIS_HEIGHT = 400

QVALUES_N = 100
FRAMESPEED = 500000

#%% Game 

def GameLoop():
    global dis
    
    dis = pygame.display.set_mode((DIS_WIDTH, DIS_HEIGHT))
    pygame.display.set_caption('Snake')
    clock = pygame.time.Clock()

    # Starting position of snake
    x1 = DIS_WIDTH / 2
    y1 = DIS_HEIGHT / 2
    x1_change = 0
    y1_change = 0
    snake_list = [(x1,y1)]
    length_of_snake = 1

    # Create first food
    foodx = round(random.randrange(0, DIS_WIDTH - BLOCK_SIZE) / 10.0) * 10.0
    foody = round(random.randrange(0, DIS_HEIGHT - BLOCK_SIZE) / 10.0) * 10.0

    dead = False
    reason = None
    steps = 0
    direction = 0
    while not dead:
        # Get action from agent
        action = learner.act(direction, snake_list, (foodx,foody))
        if action == "left":
            x1_change = -BLOCK_SIZE
            y1_change = 0
            direction = 0
        elif action == "right":
            x1_change = BLOCK_SIZE
            y1_change = 0
            direction = 1
        elif action == "up":
            y1_change = -BLOCK_SIZE
            x1_change = 0
            direction = 2
        elif action == "down":
            y1_change = BLOCK_SIZE
            x1_change = 0
            direction = 3
        steps += 1

        # Move snake
        x1 += x1_change
        y1 += y1_change
        snake_head = (x1,y1)
        snake_list.append(snake_head)

        # Check if snake is off screen
        if x1 >= DIS_WIDTH or x1 < 0 or y1 >= DIS_HEIGHT or y1 < 0:
            reason = 'Screen'
            dead = True

        # Check if snake hit tail
        if snake_head in snake_list[:-1]:
            reason = 'Tail'
            dead = True

        if steps > 700:
            reason = 'Steps'
            dead = True

        # Check if snake ate food
        if x1 == foodx and y1 == foody:
            foodx = round(random.randrange(0, DIS_WIDTH - BLOCK_SIZE) / 10.0) * 10.0
            foody = round(random.randrange(0, DIS_HEIGHT - BLOCK_SIZE) / 10.0) * 10.0
            length_of_snake += 1
            steps = 0

        # Delete the last cell since we just added a head for moving, unless we ate a food
        if len(snake_list) > length_of_snake:
            del snake_list[0]

        # Draw food, snake and update score
        dis.fill(BLUE)
        DrawFood(foodx, foody)
        DrawSnake(snake_list)
        DrawScore(length_of_snake - 1)
        pygame.display.update()

        # Update Q Table
        learner.UpdateQValues(reason)
        
        # Next Frame
        clock.tick(FRAMESPEED)

    return length_of_snake - 1, reason

def DrawFood(foodx, foody):
    pygame.draw.rect(dis, GREEN, [foodx, foody, BLOCK_SIZE, BLOCK_SIZE])   

def DrawScore(score):
    font = pygame.font.SysFont("comicsansms", 35)
    value = font.render(f"Score: {score}", True, YELLOW)
    dis.blit(value, [0, 0])

def DrawSnake(snake_list):
    for x in snake_list:
        pygame.draw.rect(dis, BLACK, [x[0], x[1], BLOCK_SIZE, BLOCK_SIZE])



#%%
game_count = 1

learner = Learner(DIS_WIDTH, DIS_HEIGHT, BLOCK_SIZE)

high_score = 0
while True:
    learner.Reset()
    learner.epsilon = learner.epsilon * learner.epsilon_decay
    if learner.epsilon < learner.epsilon_min:
        learner.epsilon = learner.epsilon_min
    score, reason = GameLoop()
    print(f"Games: {game_count}; Score: {score}; Reason: {reason};  Current high score: {high_score}; epsilon: {learner.epsilon}") # Output results of each game to console to monitor as agent is training
    if score > high_score:
        high_score = score
        print("Save Qvals")
        path_q = "qTable/"+ str(high_score)+ "," + str(game_count)+".json"
        print(path_q)
        learner.SaveQvalues(path=path_q)
    game_count += 1
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.10.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Games: 1; Score: 1; Reason: Tail;  Current high score: 0; epsilon: 0.9992
# Save Qvals
# qTable/1,1.json
# here
# Games: 2; Score: 1; Reason: Tail;  Current high score: 1; epsilon: 0.99840064
# Games: 3; Score: 0; Reason: Screen;  Current high score: 1; epsilon: 0.9976019194879999
# Games: 4; Score: 0; Reason: Steps;  Current high score: 1; epsilon: 0.9968038379524095
# Games: 5; Score: 0; Reason: Screen;  Current high score: 1; epsilon: 0.9960063948820475
# Games: 6; Score: 0; Reason: Steps;  Current high score: 1; epsilon: 0.9952095897661418
# Games: 7; Score: 0; Reason: Screen;  Current high score: 1; epsilon: 0.9944134220943289
# Games: 8; Score: 0; Reason: Screen;  Current high score: 1; epsilon: 0.9936178913566535
# Games: 9; Score: 0; Reason: Screen;  Current high score: 1; epsilon: 0.9928229970435681
# Games: 10; Score: 0; Reason: Steps;  Current high score: 1; epsilon: 0.9920287386459332
# Games: 11; Score: 0; Reason: Screen;  Current high score: 1; epsilon: 0.9912351156550164
# Games: 12; Score: 1; Reason: Tail;  Current high score: 1; epsilon: 0.9904421275624924
# Games: 13; Score: 0; Reason: Screen;  Current high score: 1; epsilon: 0.9896497738604424
# Games: 14; Score: 0; Reason: Steps;  Current high score: 1; epsilon: 0.9888580540413541
# Games: 15; Score: 0; Reason: Screen;  Current high score: 1; epsilon: 0.988066967598121
# Games: 16; Score: 0; Reason: Steps;  Current high score: 1; epsilon: 0.9872765140240425
# Games: 17; Score: 1; Reason: Tail;  Current high score: 1; epsilon: 0.9864866928128232
# Games: 18; Score: 0; Reason: Screen;  Current high score: 1; epsilon: 0.9856975034585729
# Games: 19; Score: 0; Reason: Screen;  Current high score: 1; epsilon: 0.984908945455806
# Games: 20; Score: 0; Reason: Steps;  Current high score: 1; epsilon: 0.9841210182994413
# Games: 21; Score: 0; Reason: Screen;  Current high score: 1; epsilon: 0.9833337214848017
# Games: 22; Score: 0; Reason: Screen;  Current high score: 1; epsilon: 0.9825470545076138
# Games: 23; Score: 0; Reason: Steps;  Current high score: 1; epsilon: 0.9817610168640077
# Games: 24; Score: 1; Reason: Tail;  Current high score: 1; epsilon: 0.9809756080505165
# Games: 25; Score: 1; Reason: Tail;  Current high score: 1; epsilon: 0.980190827564076
# Games: 26; Score: 0; Reason: Steps;  Current high score: 1; epsilon: 0.9794066749020248
# Games: 27; Score: 0; Reason: Steps;  Current high score: 1; epsilon: 0.9786231495621032
# Games: 28; Score: 0; Reason: Screen;  Current high score: 1; epsilon: 0.9778402510424534
# Games: 29; Score: 1; Reason: Tail;  Current high score: 1; epsilon: 0.9770579788416195
# Games: 30; Score: 0; Reason: Screen;  Current high score: 1; epsilon: 0.9762763324585462
# Games: 31; Score: 0; Reason: Screen;  Current high score: 1; epsilon: 0.9754953113925793
# Games: 32; Score: 0; Reason: Steps;  Current high score: 1; epsilon: 0.9747149151434652
# Games: 33; Score: 1; Reason: Tail;  Current high score: 1; epsilon: 0.9739351432113504
# Games: 34; Score: 0; Reason: Screen;  Current high score: 1; epsilon: 0.9731559950967813
# Games: 35; Score: 0; Reason: Steps;  Current high score: 1; epsilon: 0.9723774703007039
# Games: 36; Score: 0; Reason: Screen;  Current high score: 1; epsilon: 0.9715995683244633
# Games: 37; Score: 0; Reason: Steps;  Current high score: 1; epsilon: 0.9708222886698037
# Games: 38; Score: 0; Reason: Steps;  Current high score: 1; epsilon: 0.9700456308388679
# Games: 39; Score: 1; Reason: Tail;  Current high score: 1; epsilon: 0.9692695943341968
# Games: 40; Score: 1; Reason: Tail;  Current high score: 1; epsilon: 0.9684941786587294
# Games: 41; Score: 0; Reason: Steps;  Current high score: 1; epsilon: 0.9677193833158024
# Games: 42; Score: 0; Reason: Steps;  Current high score: 1; epsilon: 0.9669452078091497
# Games: 43; Score: 0; Reason: Steps;  Current high score: 1; epsilon: 0.9661716516429024
# Games: 44; Score: 0; Reason: Screen;  Current high score: 1; epsilon: 0.9653987143215881
# Games: 45; Score: 0; Reason: Screen;  Current high score: 1; epsilon: 0.9646263953501308
# Games: 46; Score: 1; Reason: Tail;  Current high score: 1; epsilon: 0.9638546942338507
# Games: 47; Score: 0; Reason: Screen;  Current high score: 1; epsilon: 0.9630836104784636
# Games: 48; Score: 0; Reason: Screen;  Current high score: 1; epsilon: 0.9623131435900808
# Games: 49; Score: 0; Reason: Steps;  Current high score: 1; epsilon: 0.9615432930752087
# Games: 50; Score: 0; Reason: Screen;  Current high score: 1; epsilon: 0.9607740584407485
# Games: 51; Score: 0; Reason: Screen;  Current high score: 1; epsilon: 0.9600054391939958
# Games: 52; Score: 1; Reason: Tail;  Current high score: 1; epsilon: 0.9592374348426406
# Games: 53; Score: 1; Reason: Tail;  Current high score: 1; epsilon: 0.9584700448947664
# Games: 54; Score: 0; Reason: Screen;  Current high score: 1; epsilon: 0.9577032688588506
# Games: 55; Score: 0; Reason: Steps;  Current high score: 1; epsilon: 0.9569371062437635
# Games: 56; Score: 1; Reason: Tail;  Current high score: 1; epsilon: 0.
Reason: Tail;  Current high score: 77; epsilon: 0.005
# Games: 12620; Score: 15; Reason: Tail;  Current high score: 77; epsilon: 0.005
# Games: 12621; Score: 9; Reason: Tail;  Current high score: 77; epsilon: 0.005
# Games: 12622; Score: 10; Reason: Tail;  Current high score: 77; epsilon: 0.005
# Games: 12623; Score: 2; Reason: Screen;  Current high score: 77; epsilon: 0.005
# Games: 12624; Score: 27; Reason: Tail;  Current high score: 77; epsilon: 0.005
# Games: 12625; Score: 8; Reason: Tail;  Current high score: 77; epsilon: 0.005
# Games: 12626; Score: 11; Reason: Tail;  Current high score: 77; epsilon: 0.005
# Games: 12627; Score: 4; Reason: Tail;  Current high score: 77; epsilon: 0.005
# Games: 12628; Score: 4; Reason: Tail;  Current high score: 77; epsilon: 0.005
# Games: 12629; Score: 1; Reason: Tail;  Current high score: 77; epsilon: 0.005
# Games: 12630; Score: 22; Reason: Tail;  Current high score: 77; epsilon: 0.005
# Games: 12631; Score: 10; Reason: Tail;  Current high score: 77; epsilon: 0.005
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\garrido-lestacheh\Classes\AI tools\FINAL_PROJECT\SnakeAi\SnakeGameBest.ipynb Cell 5 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/garrido-lestacheh/Classes/AI%20tools/FINAL_PROJECT/SnakeAi/SnakeGameBest.ipynb#W4sZmlsZQ%3D%3D?line=135'>136</a> if learner.epsilon < learner.epsilon_min:
#     <a href='vscode-notebook-cell:/c%3A/Users/garrido-lestacheh/Classes/AI%20tools/FINAL_PROJECT/SnakeAi/SnakeGameBest.ipynb#W4sZmlsZQ%3D%3D?line=136'>137</a>     learner.epsilon = learner.epsilon_min
# --> <a href='vscode-notebook-cell:/c%3A/Users/garrido-lestacheh/Classes/AI%20tools/FINAL_PROJECT/SnakeAi/SnakeGameBest.ipynb#W4sZmlsZQ%3D%3D?line=137'>138</a> score, reason = GameLoop()
#     <a href='vscode-notebook-cell:/c%3A/Users/garrido-lestacheh/Classes/AI%20tools/FINAL_PROJECT/SnakeAi/SnakeGameBest.ipynb#W4sZmlsZQ%3D%3D?line=138'>139</a> print(f"Games: {game_count}; Score: {score}; Reason: {reason};  Current high score: {high_score}; epsilon: {learner.epsilon}") # Output results of each game to console to monitor as agent is training
#     <a href='vscode-notebook-cell:/c%3A/Users/garrido-lestacheh/Classes/AI%20tools/FINAL_PROJECT/SnakeAi/SnakeGameBest.ipynb#W4sZmlsZQ%3D%3D?line=139'>140</a> if score > high_score:
#
# c:\Users\garrido-lestacheh\Classes\AI tools\FINAL_PROJECT\SnakeAi\SnakeGameBest.ipynb Cell 5 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/garrido-lestacheh/Classes/AI%20tools/FINAL_PROJECT/SnakeAi/SnakeGameBest.ipynb#W4sZmlsZQ%3D%3D?line=100'>101</a> DrawSnake(snake_list)
#     <a href='vscode-notebook-cell:/c%3A/Users/garrido-lestacheh/Classes/AI%20tools/FINAL_PROJECT/SnakeAi/SnakeGameBest.ipynb#W4sZmlsZQ%3D%3D?line=101'>102</a> DrawScore(length_of_snake - 1)
# --> <a href='vscode-notebook-cell:/c%3A/Users/garrido-lestacheh/Classes/AI%20tools/FINAL_PROJECT/SnakeAi/SnakeGameBest.ipynb#W4sZmlsZQ%3D%3D?line=102'>103</a> pygame.display.update()
#     <a href='vscode-notebook-cell:/c%3A/Users/garrido-lestacheh/Classes/AI%20tools/FINAL_PROJECT/SnakeAi/SnakeGameBest.ipynb#W4sZmlsZQ%3D%3D?line=104'>105</a> # Update Q Table
#     <a href='vscode-notebook-cell:/c%3A/Users/garrido-lestacheh/Classes/AI%20tools/FINAL_PROJECT/SnakeAi/SnakeGameBest.ipynb#W4sZmlsZQ%3D%3D?line=105'>106</a> learner.UpdateQValues(reason)
#
# KeyboardInterrupt:
